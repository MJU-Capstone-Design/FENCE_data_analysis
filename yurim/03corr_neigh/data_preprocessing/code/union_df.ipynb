# %%
#rest_res

# %%
import pandas as pd

mapo_res = pd.read_csv('./data/df_resmapo.csv', encoding='euc-kr')
junggu_res = pd.read_csv('./data/df_resjunggu.csv', encoding='euc-kr')
jongro_res = pd.read_csv('./data/df_resjongro.csv', encoding='euc-kr')
youngdeungpo_res = pd.read_csv('./data/df_resyoungdeungpo.csv', encoding='euc-kr')
rest_restaurant = pd.concat([mapo_res, junggu_res,jongro_res,youngdeungpo_res])

rest_restaurant.to_csv("rest_restaurant.csv", encoding='euc-kr')

# %%
a = pd.read_csv('./data/secure2.csv')

# %%
a
# Out:
#     전체  살인  강도  절도  폭력  성폭력                       주소         위도          경도  \
# 0    4   3   1   4   4    3       서울 종로구 행촌동 송월길 152  37.571795  126.962182
# 1    4   2   3   3   3    4           서울 종로구 사직로9길 5  37.575950  126.968135
# 2    2   1   1   2   2    2        서울 종로구 자하문로17길 24  37.581456  126.969412
# 3    1   1   2   1   1    1         서울 종로구 자하문로 92-1  37.584123  126.970577
# 4    2   1   1   2   2    1             서울 종로구 효자로 9  37.576754  126.973976
# 5    3   3   1   3   3    3          서울 종로구 경희궁길 6-3  37.570735  126.972189
# 6    3   1   1   4   4    2            서울 종로구 삼청로 66  37.581386  126.981106
# 7    4   1   3   5   4    4            서울 종로구 삼봉로 33  37.572899  126.979252
# 8    5   1   2   5   5    5          서울 종로구 삼일대로 386  37.568809  126.988094
# 9    5   4   4   5   5    5           서울 종로구 종로17길 4  37.570485  126.988897
# 10   5   3   4   2   3    5           서울 종로구 동호로 407  37.570720  127.001609
# 11   4   1   3   3   4    5       서울 종로구 종로41나길 24-6  37.572928  127.004847
# 12   4   2   1   4   4    5          서울 종로구 이화장2길 33  37.578577  127.006013
# 13   2   1   2   2   2    1            서울 종로구 창신길 98  37.575982  127.010507
# 14   3   1   2   2   2    4           서울 종로구 성균관로 78  37.589281  126.997590
# 15   1   1   1   1   1    2          서울 종로구 창경궁로 279  37.586091  127.001383
# 16   4   4   4   3   3    3      서울 종로구 지봉로13길 20-12  37.578477  127.013530
# 17   4   1   3   3   4    4         서울 종로구 종로58가길 19  37.572638  127.016970
# 18   3   1   1   4   4    2          서울 종로구 세검정로 226  37.600022  126.958431
# 19   3   3   2   3   5    2          서울 종로구 평창문화로 46  37.604745  126.965404
# 20   2   1   1   2   2    3           서울 마포구 상암동 8-8  37.578416  126.893892
# 21   3   3   3   2   2    3           서울 마포구 성산동 602  37.568944  126.909003
# 22   2   2   2   2   2    2        서울 마포구 연남동 373-20  37.560371  126.923748
# 23   4   2   2   2   3    4    서울 마포구 아현동 마포대로 195-1  37.552107  126.953974
# 24   3   2   1   2   3    4     서울 마포구 용강동 토정로31길 35  37.542674  126.943053
# 25   4   2   4   3   2    5      서울 마포구 창전동 독막로22길 8  37.547499  126.929153
# 6      삼청파출소  사간동, 소격동, 삼청동, 팔판동, 가회동, 화동, 재동, 안국동, 송현동, 계동,...
# 7      청진파출소                수송동, 중학동, 공평동, 견지동, 종로1가, 청진동, 종로1길
# 8      관수파출소                     관철동, 관수동, 장사동, 서린동, 종로2가, 종로3가
# 9    종로2가지구대  인사동, 낙원동, 경지동, 공평동, 묘동, 돈의동, 익선동, 경운동, 와룡동, 운니...
# 10   종로5가파출소  훈정동, 봉익동, 인의동, 연지동, 예지동, 원남동, 묘동, 와룡동, 권농동, 연건...
# 11     효제파출소                   효제동, 충신동, 종로5가동, 종로6가동, 연건동, 이화동
# 12    대학로파출소    명륜2가동, 명륜4가동, 와룡동, 권농동, 동숭동, 이화동, 연건동, 원남동, 충신동
# 13     덕산파출소                                               창신2동
# 14     명륜파출소                         명륜1가동, 명륜3가동, 명륜2가동, 명륜4가동
# 15     혜화파출소                                                혜화동
# 16     창신파출소                             창신1동, 창신3동, 숭인1동, 숭인2동
# 17     동묘파출소                                         창신1동, 숭인2동
# 18    세검정파출소                            부암동, 홍지동, 신영동, 평창동, 구기동
# 19     평창파출소                                      평창동, 신영동, 구기동
# 20     상암파출소                                           상암동, 성산동
# 21    월드컵지구대                           성산1동, 중동, 성산2동, 서교동, 상암동
# 22     연남파출소                                           연남동, 동교동
# 23     공덕지구대                 아현1동, 아현2동, 아현3동, 공덕1동, 공덕2동, 신공덕동
# 24     용강지구대                       도화동, 용강동, 염리동, 토정동, 대흥동, 신수동
# 25     서강지구대       창전동, 상수동, 당인동, 신정동, 구수동, 하중동, 노고산동, 대흥동, 서교동
# 26     홍익지구대                                      서교동, 합정동, 동교동
# 27     망원파출소                                         망원1동, 망원2동
# 28     문래지구대  문래동, 도림동, 영등포본동, 도신로29길, 도신로29아길, 영신로9길, 영신로9라...
# 29   영등포역파출소                              영등포본동, 영등포동1가, 영등포동4가
# 30     당산파출소                      당산2동, 당산동6가, 양평2동, 양평동3가, 양화동
# 31    대림3파출소                                               대림3동
# 32     대림파출소                                         대림1동, 대림2동
# 33     신풍지구대                             신길3동, 신길5동, 신길6동, 신길7동
# 34     양평파출소           양평동1가, 양평동2가, 양평동3가, 당산동1가, 당산동2가, 당산동3가
# 35     신길지구대                             신길1동, 신길2동, 신길4동, 신길7동
# 36    여의도지구대                                               여의도동
# 37     중앙지구대  영등포동1가, 영등포동2가, 영등포동3가, 영등포동4가, 영등포동5가, 영등포동6가...
# 38    세종로파출소                       세종로동, 도렴동, 당주동, 신문로1가, 신문로2가
# 39    태평로파출소  남대문로1가, 다동, 무교동, 을지로1가, 을지로2가, 삼각동, 수하동, 장교동, ...
# 40     신당파출소                                          신당5동, 동화동
# 41     광희지구대  다산로47길, 퇴계로27길, 퇴계로73길, 퇴계로75길, 장충단로8길, 장충단로8가...
# 42     약수지구대                                      약수동, 청구동, 다산동
# 43    서울역파출소                          남대문로5가, 봉래동1가, 봉래동2가, 순화동
# 44     중림파출소                           만리동1가, 만리동2가, 의주로2가, 중림동
# 45    서소문파출소  남대문로4가, 봉래동1가, 서소문동, 순화동, 의주로1가, 정동, 충정로1가, 태평...
# 46     명동파출소  남대문로2가, 남산동1가, 남산동2가, 남산동3가, 명동1가, 명동2가, 예장동, ...
# 47  을지로3가파출소  저동2가, 초동, 수표동, 입정동, 산림동, 삼일대로8길, 삼일대로12길, 퇴계로2...
# 48     을지지구대  방산동, 오장동, 주교동, 충무로5가, 을지로27길, 을지로28길, 을지로30길, ...
# 49     충무파출소  필동1가, 필동2가, 필동3가, 주차동, 남학동, 상일대로2길, 삼일대로4길, 삼일...
# 50     회현파출소                          남대문로5가, 남창동, 회현동1가, 회현동2가
# 51    남대문파출소                  남대문로3가, 남대문로4가, 남창동, 충무로1가, 회현동1가
# 52     장충파출소  서애로1길, 장충1가, 동호로24길, 동호로25길, 동호로25가길, 동호로27길, ...

# %%
a
# Out:
# Empty DataFrame
# Columns: [전체, 살인, 강도, 절도, 폭력, 성폭력, 주소, 위도, 경도, 지구대, 관할구역, Unnamed: 12]
# Index: []

# %%
import pandas as pd

youngsan_res = pd.read_csv('./data/df_resyoungsan.csv', encoding='euc-kr')
gangnam_res = pd.read_csv('./data/df_resgangnam.csv', encoding = 'euc-kr')
geumcheon_res = pd.read_csv('./data/df_resgeumcheon.csv', encoding = 'euc-kr')
guro_res = pd.read_csv('./data/df_resguro.csv', encoding = 'euc-kr')

rest_restaurant2 = pd.concat([youngsan_res, gangnam_res,geumcheon_res,guro_res])

rest_restaurant2.to_csv("rest_restaurant2.csv", encoding='euc-kr')

# %%
import pandas as pd

rest_pre = pd.read_csv('./data/df_rest_restaurant.csv', encoding = 'euc-kr')
rest_post = pd.read_csv('./data/rest_restaurant2.csv', encoding = 'euc-kr')

rest_restaurant_fin = pd.concat([rest_pre, rest_post])

rest_restaurant_fin.to_csv("df_rest_restaurant2.csv", encoding='euc-kr')

# %%
import pandas as pd

gangseo_res = pd.read_csv('./data/df_resgangseo.csv', encoding = 'euc-kr')
yangcheon_res = pd.read_csv('./data/df_resyangcheon.csv', encoding = 'euc-kr')
nowon_res = pd.read_csv('./data/df_resnowon.csv', encoding = 'euc-kr')
sungbuk_res = pd.read_csv('./data/df_ressungbuk.csv', encoding = 'euc-kr')
dobong_res = pd.read_csv('./data/df_resdobong.csv', encoding = 'euc-kr')
eunpeung_res = pd.read_csv('./data/df_reseunpeung.csv', encoding = 'euc-kr')

rest_restaurant3 = pd.concat([gangseo_res, yangcheon_res,nowon_res,sungbuk_res,dobong_res,eunpeung_res])

rest_restaurant3.to_csv("rest_restaurant3.csv", encoding='euc-kr')
