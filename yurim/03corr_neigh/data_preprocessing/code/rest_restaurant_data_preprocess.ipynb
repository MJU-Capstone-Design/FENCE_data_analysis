# %%
import numpy as np
import pandas as pd
junggu = pd.read_csv('res_junggu.csv', encoding = 'euc-kr')
junggu
# Out:
#         시군구코드  업종코드    년도  업소일련번호    업종명     허가신고일                       업소명  \
# 0     3010000   104  1904     583  휴게음식점  19040808                         .
# 1     3010000   104  1936    1068  휴게음식점  19361023                        정동
# 2     3010000   104  1965     200  휴게음식점  19650724                        장군
# 3     3010000   104  1966     905  휴게음식점  19660720                        은호
# 4     3010000   104  1966     970  휴게음식점  19660912                        수련
# ...       ...   ...   ...     ...    ...       ...                       ...
# 7692  3010000   104  2020      85  휴게음식점  20200429                   제주은갈치유통
# 7693  3010000   104  2020      86  휴게음식점  20200429                      밥부리또
# 7694  3010000   104  2020      87  휴게음식점  20200501  커피앤시가렛(coffee&cigaratte)
# 7695  3010000   104  2020      88  휴게음식점  20200501             더피크(The Peak)
# 7696  3010000   104  2020      89  휴게음식점  20200504                사이로(SAISO)
#
#                                        소재지도로명  \
# 0
# 1
# 2
# 3
# 4
# ...                                       ...
# 7692    서울특별시 중구 소공로 63 신세계백화점건물 지하1층 (충무로1가)
# 7693    서울특별시 중구 소공로 63 신세계백화점건물 지하1층 (충무로1가)
# 7694  서울특별시 중구 서소문로 116 유원빌딩 17층 1702호 (서소문동)
# 7695             서울특별시 중구 필동로 15-11 4층 (필동2가)
# 7696             서울특별시 중구 퇴계로86가길 15 1층 (신당동)
#
#                                   소재지지번  영업장면적(㎡)  ... 진열(판매)대면적(㎡)  \
# 0                  서울특별시 중구 무학동  37번지       89.50  ...          NaN
# 1             서울특별시 중구 을지로2가  18번지 3호      111.60  ...          NaN
# 2              서울특별시 중구 신당동  369번지 0호       24.70  ...          NaN
# 3             서울특별시 중구 의주로2가  92번지 1호      101.14  ...          NaN
# 4              서울특별시 중구 서소문동  84번지 1호       63.68  ...          NaN
# ...                                 ...       ...  ...          ...
# 7692  서울특별시 중구 충무로1가  52번지 5호  신세계백화점건물       NaN  ...          NaN
# 7693  서울특별시 중구 충무로1가  52번지 5호  신세계백화점건물       NaN  ...          NaN
# 7694      서울특별시 중구 서소문동  75번지 95호  유원빌딩       NaN  ...          NaN
# 7695           서울특별시 중구 필동2가  70번지 1호         NaN  ...          NaN
# 7696          서울특별시 중구 신당동  52번지 134호         NaN  ...          NaN
#
#       창고(보관소)면적(㎡)                허가(신고)번호  참고사항 조건부허가시작일  조건부허가종료일 조건부허가신고사유  \
# 0              NaN  3010000-104-1904-00583   NaN      NaN       NaN       NaN
# 1              NaN  3010000-104-1936-01068   NaN      NaN       NaN       NaN
# 2              NaN  3010000-104-1965-00200   NaN      NaN       NaN       NaN
# 3              NaN  3010000-104-1966-00905   NaN      NaN       NaN       NaN
# 4              NaN  3010000-104-1966-00970   NaN      NaN       NaN       NaN
# ...            ...                     ...   ...      ...       ...       ...
# 7692           NaN  3010000-104-2020-00085   NaN      NaN       NaN       NaN
# 7693           NaN  3010000-104-2020-00086   NaN      NaN       NaN       NaN
# 7694           NaN  3010000-104-2020-00087   NaN      NaN       NaN       NaN
# 7695           NaN  3010000-104-2020-00088   NaN      NaN       NaN       NaN
# 7696           NaN  3010000-104-2020-00089   NaN      NaN       NaN       NaN
#
#      신고조건 내외국인구분    국적
# 0     NaN    내국인   NaN
# 1     NaN    내국인   NaN
# 2     NaN    내국인   NaN
# 3     NaN    내국인   NaN
# 4     NaN    내국인   NaN
# ...   ...    ...   ...
# 7692  NaN    내국인  대한민국
# 7693  NaN    내국인  대한민국
# 7694  NaN    내국인  대한민국
# 7695  NaN    내국인  대한민국
# 7696  NaN    내국인  대한민국
#
# [7697 rows x 56 columns]

# %%
df_junggu = junggu[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_junggu.head(20)
# Out:
#       업종명      업소명                    소재지도로명                       소재지지번  \
# 0   휴게음식점        .                                  서울특별시 중구 무학동  37번지
# 1   휴게음식점       정동                             서울특별시 중구 을지로2가  18번지 3호
# 2   휴게음식점       장군                              서울특별시 중구 신당동  369번지 0호
# 3   휴게음식점       은호                             서울특별시 중구 의주로2가  92번지 1호
# 4   휴게음식점       수련                              서울특별시 중구 서소문동  84번지 1호
# 5   휴게음식점       수도                            서울특별시 중구 을지로5가  273번지 4호
# 6   휴게음식점     은자다방                            서울특별시 중구 남대문로3가  30번지 7호
# 7   휴게음식점      푸른들                            서울특별시 중구 남대문로3가  92번지 2호
# 8   휴게음식점       로방                              서울특별시 중구 삼각동  113번지 0호
# 9   휴게음식점      오두막                               서울특별시 중구 무학동  50번지 2호
# 10  휴게음식점     남지다방                             서울특별시 중구 중림동  67번지 0호  68
# 11  휴게음식점       만리                             서울특별시 중구 만리동2가  24번지 1호
# 12  휴게음식점  쟈뎅커피전문점                             서울특별시 중구 저동2가  48번지 20호
# 13  휴게음식점       명보                               서울특별시 중구 중림동  18번지 7호
# 14  휴게음식점       삼옥                               서울특별시 중구 중림동  93번지 3호
# 15  휴게음식점       백조  서울특별시 중구 을지로35길 35 (주교동)    서울특별시 중구 주교동  311번지 3호
# 16  휴게음식점        랑                               서울특별시 중구 남창동  9번지 15호
# 17  휴게음식점       초은                            서울특별시 중구 을지로3가  251번지 1호
# 18  휴게음식점      사랑방                            서울특별시 중구 태평로1가  31번지 23호
# 19  휴게음식점       부촌                                서울특별시 중구 예관동  1번지 3호
#
#     행정동명        폐업일자  폐업구분     업태명
# 0    신당동  19930326.0  자진폐업      다방
# 1     명동  19960620.0  행정처분      다방
# 2    신당동  19960112.0  자진폐업  일반조리판매
# 3    중림동  19900706.0  자진폐업      다방
# 4    소공동  19961010.0  자진폐업      다방
# 5   을지로동  20031010.0  자진폐업      다방
# 6    소공동  20031017.0  자진폐업      다방
# 7    소공동  20071120.0  자진폐업      다방
# 8     명동  19890719.0  자진폐업      다방
# 9    신당동  19951101.0  자진폐업      다방
# 10   중림동  20030402.0  자진폐업      다방
# 11   중림동  19970227.0  자진폐업      다방
# 12  을지로동  19971015.0  자진폐업      다방
# 13   중림동  19910912.0  자진폐업      다방
# 14   중림동  19911227.0  자진폐업      다방
# 15  을지로동         NaN   NaN      다방
# 16   회현동  19920129.0  행정처분      다방
# 17  을지로동  19921210.0  자진폐업      다방
# 18    명동  20001130.0  자진폐업      다방
# 19   광희동         NaN   NaN      다방

# %%
df_junggu[df_junggu['폐업구분'].isnull()]
# Out:
#         업종명                       업소명  \
# 15    휴게음식점                        백조
# 19    휴게음식점                        부촌
# 22    휴게음식점                        을호
# 32    휴게음식점                       서울역
# 38    휴게음식점                     문화커피숍
# ...     ...                       ...
# 7692  휴게음식점                   제주은갈치유통
# 7693  휴게음식점                      밥부리또
# 7694  휴게음식점  커피앤시가렛(coffee&cigaratte)
# 7695  휴게음식점             더피크(The Peak)
# 7696  휴게음식점                사이로(SAISO)
#
#                                        소재지도로명  \
# 15                   서울특별시 중구 을지로35길 35 (주교동)
# 19
# 22                 서울특별시 중구 장충단로13길 7 (을지로6가)
# 32                  서울특별시 중구 세종대로 13 (남대문로5가)
# 38                     서울특별시 중구 수표로 30 (저동2가)
# ...                                       ...
# 7692    서울특별시 중구 소공로 63 신세계백화점건물 지하1층 (충무로1가)
# 7693    서울특별시 중구 소공로 63 신세계백화점건물 지하1층 (충무로1가)
# 7694  서울특별시 중구 서소문로 116 유원빌딩 17층 1702호 (서소문동)
# 7695             서울특별시 중구 필동로 15-11 4층 (필동2가)
# 7696             서울특별시 중구 퇴계로86가길 15 1층 (신당동)
#
#                                   소재지지번  행정동명  폐업일자 폐업구분     업태명
# 15             서울특별시 중구 주교동  311번지 3호    을지로동   NaN  NaN      다방
# 19               서울특별시 중구 예관동  1번지 3호     광희동   NaN  NaN      다방
# 22           서울특별시 중구 을지로6가  18번지 95호     광희동   NaN  NaN      다방
# 32            서울특별시 중구 남대문로5가  6번지 8호     회현동   NaN  NaN      다방
# 38            서울특별시 중구 저동2가  47번지 15호    을지로동   NaN  NaN      다방
# ...                                 ...   ...   ...  ...     ...
# 7692  서울특별시 중구 충무로1가  52번지 5호  신세계백화점건물   회현동   NaN  NaN  일반조리판매
# 7693  서울특별시 중구 충무로1가  52번지 5호  신세계백화점건물   회현동   NaN  NaN  일반조리판매
# 7694      서울특별시 중구 서소문동  75번지 95호  유원빌딩   소공동   NaN  NaN     커피숍
# 7695           서울특별시 중구 필동2가  70번지 1호      필동   NaN  NaN     커피숍
# 7696          서울특별시 중구 신당동  52번지 134호     신당동   NaN  NaN     커피숍
#
# [3172 rows x 8 columns]

# %%
df_junggu = df_junggu[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_junggu
# Out:
#         업종명                       업소명  \
# 0     휴게음식점                         .
# 1     휴게음식점                        정동
# 2     휴게음식점                        장군
# 3     휴게음식점                        은호
# 4     휴게음식점                        수련
# ...     ...                       ...
# 7692  휴게음식점                   제주은갈치유통
# 7693  휴게음식점                      밥부리또
# 7694  휴게음식점  커피앤시가렛(coffee&cigaratte)
# 7695  휴게음식점             더피크(The Peak)
# 7696  휴게음식점                사이로(SAISO)
#
#                                        소재지도로명  \
# 0
# 1
# 2
# 3
# 4
# ...                                       ...
# 7692    서울특별시 중구 소공로 63 신세계백화점건물 지하1층 (충무로1가)
# 7693    서울특별시 중구 소공로 63 신세계백화점건물 지하1층 (충무로1가)
# 7694  서울특별시 중구 서소문로 116 유원빌딩 17층 1702호 (서소문동)
# 7695             서울특별시 중구 필동로 15-11 4층 (필동2가)
# 7696             서울특별시 중구 퇴계로86가길 15 1층 (신당동)
#
#                                   소재지지번 행정동명     업태명
# 0                  서울특별시 중구 무학동  37번지    신당동      다방
# 1             서울특별시 중구 을지로2가  18번지 3호     명동      다방
# 2              서울특별시 중구 신당동  369번지 0호    신당동  일반조리판매
# 3             서울특별시 중구 의주로2가  92번지 1호    중림동      다방
# 4              서울특별시 중구 서소문동  84번지 1호    소공동      다방
# ...                                 ...  ...     ...
# 7692  서울특별시 중구 충무로1가  52번지 5호  신세계백화점건물  회현동  일반조리판매
# 7693  서울특별시 중구 충무로1가  52번지 5호  신세계백화점건물  회현동  일반조리판매
# 7694      서울특별시 중구 서소문동  75번지 95호  유원빌딩  소공동     커피숍
# 7695           서울특별시 중구 필동2가  70번지 1호     필동     커피숍
# 7696          서울특별시 중구 신당동  52번지 134호    신당동     커피숍
#
# [7697 rows x 6 columns]

# %%
jungrang = pd.read_csv('res_jungrang.csv', encoding = 'euc-kr')
df_jungrang = jungrang[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_jungrang[df_jungrang['폐업구분'].isnull()]
df_jungrang = df_jungrang[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_jungrang
# Out:
#         업종명             업소명  \
# 0     휴게음식점              등대
# 1     휴게음식점           청학커피숍
# 2     휴게음식점              은하
# 3     휴게음식점              중앙
# 4     휴게음식점               영
# ...     ...             ...
# 2913  휴게음식점       GS25 묵동사랑
# 2914  휴게음식점   죠스떡볶이 상봉망우엠코점
# 2915  휴게음식점     플레이스(place)
# 2916  휴게음식점      이마트24 중화역점
# 2917  휴게음식점  (주)코스트코코리아푸드코트
#
#                                                  소재지도로명  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 2913                           서울특별시 중랑구 공릉로 68 1층 (묵동)
# 2914  서울특별시 중랑구 망우로 353 비주거동 1층 C-106호 (상봉동 상봉 프레미어스...
# 2915                      서울특별시 중랑구 동일로129길 53 1층 (중화동)
# 2916                         서울특별시 중랑구 동일로 799 1층 (중화동)
# 2917                            서울특별시 중랑구 망우로 336 (상봉동)
#
#                                   소재지지번   행정동명       업태명
# 0              서울특별시 중랑구 묵동  238번지 8호     묵제1동        다방
# 1             서울특별시 중랑구 상봉동  136번지 6호    상봉제2동        다방
# 2             서울특별시 중랑구 상봉동  108번지 2호    상봉제1동        다방
# 3           서울특별시 중랑구 상봉동  130번지 130호    상봉제1동        다방
# 4            서울특별시 중랑구 망우동  340번지 22호     망우본동        다방
# ...                                 ...    ...       ...
# 2913           서울특별시 중랑구 묵동  318번지 1호     묵제1동       편의점
# 2914  서울특별시 중랑구 상봉동  500번지  상봉 프레미어스 엠코  상봉제1동  기타 휴게음식점
# 2915         서울특별시 중랑구 중화동  314번지 45호    중화제2동       커피숍
# 2916         서울특별시 중랑구 중화동  305번지 42호    중화제2동       편의점
# 2917           서울특별시 중랑구 상봉동  81번지 0호    상봉제2동     패스트푸드
#
# [2918 rows x 6 columns]

# %%
mapo = pd.read_csv('res_mapo.csv', encoding = 'euc-kr')
df_mapo = mapo[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_mapo[df_mapo['폐업구분'].isnull()]
df_mapo = df_mapo[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_mapo
# Out:
#         업종명           업소명                                             소재지도로명  \
# 0     휴게음식점            삼성
# 1     휴게음식점         새명커피숍
# 2     휴게음식점            샬롬
# 3     휴게음식점             희                           서울특별시 마포구 마포대로 181 (아현동)
# 4     휴게음식점         샤넬커피샵
# ...     ...           ...                                                ...
# 6029  휴게음식점  오베스트(AOVEST)            서울특별시 마포구 연남로11길 41 아름피아노 1층 1-2호 (성산동)
# 6030  휴게음식점   지에스25 S공덕역점              서울특별시 마포구 마포대로 92 효성해링턴 스퀘어 지3층 (도화동)
# 6031  휴게음식점            더빅                  서울특별시 마포구 월드컵로 50 1층 101-B호 (서교동)
# 6032  휴게음식점        플라잉 웨일                      서울특별시 마포구 월드컵로10길 15 1층 (서교동)
# 6033  휴게음식점          꿀스커피  서울특별시 마포구 매봉산로 75 디디엠씨(DDMC) 지하1층 B107푸드코트내16)...
#
#                                    소재지지번   행정동명       업태명
# 0             서울특별시 마포구 신수동  448번지 10호      신수동        다방
# 1              서울특별시 마포구 아현동  270번지 1호      아현동        다방
# 2             서울특별시 마포구 공덕동  105번지 62호      공덕동        다방
# 3              서울특별시 마포구 아현동  618번지 7호      아현동        다방
# 4              서울특별시 마포구 염리동  148번지 9호      염리동        다방
# ...                                  ...    ...       ...
# 6029      서울특별시 마포구 성산동  610번지 3호  아름피아노  성산제1동  기타 휴게음식점
# 6030  서울특별시 마포구 도화동  25번지 13호  효성해링턴 스퀘어    공덕동  기타 휴게음식점
# 6031          서울특별시 마포구 서교동  444번지 17호      서교동  기타 휴게음식점
# 6032          서울특별시 마포구 서교동  476번지 32호      서교동  기타 휴게음식점
# 6033   서울특별시 마포구 상암동  1610번지  디디엠씨(DDMC)    상암동  기타 휴게음식점
#
# [6034 rows x 6 columns]

# %%
df_junggu.to_csv("df_resjunggu.csv", encoding='euc-kr')

# %%
df_jungrang.to_csv("df_resjungrang.csv", encoding='euc-kr')

# %%
df_mapo.to_csv("df_resmapo.csv", encoding='euc-kr')

# %%
dobong = pd.read_csv('res_dobong.csv', encoding = 'euc-kr')
df_dobong = dobong[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_dobong[df_dobong['폐업구분'].isnull()]
df_dobong = df_dobong[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_dobong
# Out:
#         업종명               업소명                       소재지도로명  \
# 0     휴게음식점                수정  서울특별시 도봉구 덕릉로 253 지하1층 (창동)
# 1     휴게음식점                동화     서울특별시 도봉구 도봉로110길 9 (창동)
# 2     휴게음식점               원다방  서울특별시 도봉구 덕릉로 212 지하1층 (창동)
# 3     휴게음식점        세븐일레븐(창동점)    서울특별시 도봉구 덕릉로63가길 42 (창동)
# 4     휴게음식점        세븐일레븐(창동점)    서울특별시 도봉구 덕릉로63가길 42 (창동)
# ...     ...               ...                          ...
# 2152  휴게음식점           메가웹스테이션
# 2153  휴게음식점             명가손만두
# 2154  휴게음식점            창동두에꼬제
# 2155  휴게음식점        88s' TRUCK
# 2156  휴게음식점  미니블랙(MINI BLACK)
#
#                                                소재지지번   행정동명     업태명
# 0                          서울특별시 도봉구 창동  601번지 32호     창제2동      다방
# 1                          서울특별시 도봉구 창동  655번지 10호     창제1동      다방
# 2                      서울특별시 도봉구 창동  552번지 42호  지하1층   창제3동      다방
# 3                          서울특별시 도봉구 창동  593번지 12호     창제2동     편의점
# 4                          서울특별시 도봉구 창동  593번지 12호     창제2동     편의점
# ...                                              ...    ...     ...
# 2152                     서울특별시 도봉구 창동  75번지 1호  (5층)   창제5동  일반조리판매
# 2153                  서울특별시 도봉구 도봉동  598번지 19호  (1층)  도봉제1동  일반조리판매
# 2154       서울특별시 도봉구 창동  1번지 9호  플랫폼 창동 61 2층 레스토랑 1   창제4동   패스트푸드
# 2155    서울특별시 도봉구 창동  635번지 42호  제6회 2018 창2동 에코벚꽃축제   창제2동    푸드트럭
# 2156  서울특별시 도봉구 창동  635번지 42호  제7회 2019년 창2동 에코 벚꽃축제   창제1동    푸드트럭
#
# [2157 rows x 6 columns]

# %%
dongdaemoon = pd.read_csv('res_dongdaemoon.csv', encoding = 'euc-kr')
df_dongdaemoon = dongdaemoon[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_dongdaemoon[df_dongdaemoon['폐업구분'].isnull()]
df_dongdaemoon = df_dongdaemoon[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_dongdaemoon
# Out:
#         업종명                     업소명                                    소재지도로명  \
# 0     휴게음식점                      파리
# 1     휴게음식점                      양지                  서울특별시 동대문구 이문로 144 (이문동)
# 2     휴게음식점                    동화다방                    서울특별시 동대문구 왕산로 4 (신설동)
# 3     휴게음식점                     새마을
# 4     휴게음식점                      동아
# ...     ...                     ...                                       ...
# 3972  휴게음식점                    소예다방            서울특별시 동대문구 고산자로62길 12 1층 (제기동)
# 3973  휴게음식점            메가엠지씨커피 경희대점               서울특별시 동대문구 경희대로 18 1층 (회기동)
# 3974  휴게음식점             릴리엔(lilien)  서울특별시 동대문구 이문로 164 C&J오피스텔 1층 102호 (이문동)
# 3975  휴게음식점                    벨 템포         서울특별시 동대문구 장한로31길 8 1층 101호 (장안동)
# 3976  휴게음식점  스윙바이 카페(swing by cafe)           서울특별시 동대문구 답십리로59길 24 1층 (답십리동)
#
#                                     소재지지번    행정동명  업태명
# 0              서울특별시 동대문구 전농동  496번지 1호     전농제1동   다방
# 1             서울특별시 동대문구 이문동  258번지 17호     이문제1동   다방
# 2              서울특별시 동대문구 신설동  101번지 7호       용신동   다방
# 3             서울특별시 동대문구 전농동  655번지 30호     전농제1동   다방
# 4             서울특별시 동대문구 용두동  119번지 15호       용신동   다방
# ...                                   ...     ...  ...
# 3972         서울특별시 동대문구 제기동  122번지 486호       제기동  커피숍
# 3973            서울특별시 동대문구 회기동  31번지 1호       회기동  커피숍
# 3974  서울특별시 동대문구 이문동  255번지 188호  C&J오피스텔   이문제1동  커피숍
# 3975           서울특별시 동대문구 장안동  304번지 4호     장안제1동  커피숍
# 3976          서울특별시 동대문구 답십리동  1번지 259호    답십리제1동  커피숍
#
# [3977 rows x 6 columns]

# %%
dongjak = pd.read_csv('res_dongjak.csv', encoding = 'euc-kr')
df_dongjak = dongjak[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_dongjak[df_dongjak['폐업구분'].isnull()]
df_dongjak = df_dongjak[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_dongjak
# Out:
#         업종명        업소명                                     소재지도로명  \
# 0     휴게음식점      로타리다방
# 1     휴게음식점       지성다방
# 2     휴게음식점      커피하우스
# 3     휴게음식점         아씨
# 4     휴게음식점          별
# ...     ...        ...                                        ...
# 3373  휴게음식점      엄마네반찬  서울특별시 동작구 만양로 84 지하1층 6호 (노량진동 삼익주상복합아파트)
# 3374  휴게음식점      분식라운지               서울특별시 동작구 여의대방로 80 1층 (신대방동)
# 3375  휴게음식점     곽선생왕만두              서울특별시 동작구 서달로 159 가동 1층 (흑석동)
# 3376  휴게음식점  카페코지 노량진점                 서울특별시 동작구 만양로 42 1층 (노량진동)
# 3377  휴게음식점       호밀호두               서울특별시 동작구 여의대방로 196 1층 (대방동)
#
#                                  소재지지번    행정동명       업태명
# 0            서울특별시 동작구 상도동  701번지 3호     상도제1동        다방
# 1            서울특별시 동작구 상도동  187번지 1호     상도제3동        다방
# 2             서울특별시 동작구 본동  399번지 3호    노량진제1동        다방
# 3          서울특별시 동작구 노량진동  240번지 27호    노량진제2동        다방
# 4         서울특별시 동작구 노량진동  307번지 159호    노량진제2동        다방
# ...                                ...     ...       ...
# 3373  서울특별시 동작구 노량진동  330번지  삼익주상복합아파트  노량진제1동    일반조리판매
# 3374       서울특별시 동작구 신대방동  498번지 51호    신대방제2동    일반조리판매
# 3375        서울특별시 동작구 흑석동  100번지 20호       흑석동  기타 휴게음식점
# 3376      서울특별시 동작구 노량진동  215번지 139호    노량진제1동       커피숍
# 3377        서울특별시 동작구 대방동  385번지 14호       대방동  기타 휴게음식점
#
# [3378 rows x 6 columns]

# %%
eunpeung = pd.read_csv('res_eunpeung.csv', encoding = 'euc-kr')
df_eunpeung = eunpeung[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_eunpeung[df_eunpeung['폐업구분'].isnull()]
df_eunpeung = df_eunpeung[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_eunpeung
# Out:
#         업종명            업소명                                소재지도로명  \
# 0     휴게음식점           해태다방
# 1     휴게음식점        케익다운제과점
# 2     휴게음식점           낙원다방
# 3     휴게음식점            은하수
# 4     휴게음식점           삼화다방
# ...     ...            ...                                   ...
# 3502  휴게음식점      씨유 대조디오빌점           서울특별시 은평구 서오릉로 118 1층 (대조동)
# 3503  휴게음식점           공방별숲          서울특별시 은평구 은평로10길 28 1층 (응암동)
# 3504  휴게음식점  Pisces (파이시스)  서울특별시 은평구 진흥로 13-2 연서빌딩 1층 좌측호 (역촌동)
# 3505  휴게음식점     지에스25 불광행복          서울특별시 은평구 통일로92길 38 1층 (불광동)
# 3506  휴게음식점            덕9네            서울특별시 은평구 서오릉로15길 15 (구산동)
#
#                                    소재지지번   행정동명     업태명
# 0        서울특별시 은평구 응암동  738번지 0호  해태드림마트  응암제1동      다방
# 1             서울특별시 은평구 대조동  224번지 24호      대조동     과자점
# 2        서울특별시 은평구 응암동  87번지 10호  (지하1층)  응암제1동      다방
# 3        서울특별시 은평구 대조동  185번지 5호  (지하1층)    대조동      다방
# 4         서울특별시 은평구 응암동  97번지 1호  (지상2층)  응암제1동      다방
# ...                                  ...    ...     ...
# 3502         서울특별시 은평구 대조동  49번지 24호  1층    대조동     편의점
# 3503         서울특별시 은평구 응암동  101번지 7호  1층  응암제1동     커피숍
# 3504  서울특별시 은평구 역촌동  43번지 53호 1층 연서빌딩-좌측    역촌동     커피숍
# 3505       서울특별시 은평구 불광동  445번지 338호 1층   불광제1동     편의점
# 3506          서울특별시 은평구 구산동  209번지 18호      구산동  일반조리판매
#
# [3507 rows x 6 columns]

# %%
gangbook = pd.read_csv('res_gangbook.csv', encoding = 'euc-kr')
df_gangbook = gangbook[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_gangbook[df_gangbook['폐업구분'].isnull()]
df_gangbook = df_gangbook[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_gangbook
# Out:
#         업종명          업소명                                소재지도로명  \
# 0     휴게음식점         대호다방
# 1     휴게음식점           양지
# 2     휴게음식점          새다방
# 3     휴게음식점         연꽃다방
# 4     휴게음식점       부산뉴욕제과
# ...     ...          ...                                   ...
# 3259  휴게음식점      카페 플로라미  서울특별시 강북구 오패산로77길 32 101호 (번동 파크애비뉴)
# 3260  휴게음식점      카페 플로라미  서울특별시 강북구 오패산로77길 32 101호 (번동 파크애비뉴)
# 3261  휴게음식점  씨유(CU)미아으뜸점          서울특별시 강북구 도봉로49길 54 1층 (미아동)
# 3262  휴게음식점       카페별책부록   서울특별시 강북구 오현로 145 강북문화정보도서관 1층 (번동)
# 3263  휴게음식점       카페별책부록   서울특별시 강북구 오현로 145 강북문화정보도서관 1층 (번동)
#
#                                    소재지지번  행정동명  업태명
# 0              서울특별시 강북구 미아동  70번지 26호     NaN   다방
# 1              서울특별시 강북구 미아동  465번지 6호     송천동   다방
# 2              서울특별시 강북구 수유동  174번지 1호     NaN   다방
# 3               서울특별시 강북구 미아동  67번지 1호     송중동   다방
# 4             서울특별시 강북구 미아동  628번지 11호     송천동  과자점
# ...                                  ...   ...  ...
# 3259  서울특별시 강북구 번동  446번지 57호  파크애비뉴-101   번1동  커피숍
# 3260  서울특별시 강북구 번동  446번지 57호  파크애비뉴-101  번제1동  커피숍
# 3261           서울특별시 강북구 미아동  301번지 5호     미아동  편의점
# 3262      서울특별시 강북구 번동  147번지  강북문화정보도서관   번2동  커피숍
# 3263      서울특별시 강북구 번동  147번지  강북문화정보도서관  번제2동  커피숍
#
# [3264 rows x 6 columns]

# %%
gangnam = pd.read_csv('res_gangnam.csv', encoding = 'euc-kr')
df_gangnam = gangnam[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_gangnam[df_gangnam['폐업구분'].isnull()]
df_gangnam = df_gangnam[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_gangnam
# Out:
#          업종명                업소명                                      소재지도로명  \
# 0      휴게음식점      미칠비루 디져트 아뜰리에            서울특별시 강남구 일원로5길 68 1층 101호 (일원동)
# 1      휴게음식점                모임터            서울특별시 강남구 삼성로 319 지하1층 01호 (대치동)
# 2      휴게음식점  (주)더더다다 퀸마마마켓 도산점       서울특별시 강남구 압구정로46길 50 지상1층 (신사동 퀸마마마켓)
# 3      휴게음식점                파서루                서울특별시 강남구 광평로46길 5 12층 (수서동)
# 4      휴게음식점              카페퓨리티  서울특별시 강남구 언주로 615 지상1층 111호 (논현동 강남YMCA회관)
# ...      ...                ...                                         ...
# 13853  휴게음식점           둥구나무 사당점         서울특별시 강남구 테헤란로 517 현대백화점 지하1층 (삼성동)
# 13854  휴게음식점               둥구나무         서울특별시 강남구 테헤란로 517 현대백화점 지하1층 (삼성동)
# 13855  휴게음식점               청담스파                서울특별시 강남구 학동로 419 지하1층 (청담동)
# 13856  휴게음식점             청담불한증막                서울특별시 강남구 학동로 419 지하1층 (청담동)
# 13857  휴게음식점                 힐링          서울특별시 강남구 언주로159길 10 1층 101호 (신사동)
#
#                                      소재지지번  행정동명     업태명
# 0                   서울특별시 강남구 일원동  655번지    일원본동     커피숍
# 1        서울특별시 강남구 대치동  931번지 25호  지하1층-01  대치1동     커피숍
# 2      서울특별시 강남구 신사동  649번지 8호  퀸마마마켓 지상1층   신사동     커피숍
# 3                서울특별시 강남구 수서동  450번지 3호     수서동  일반조리판매
# 4                서울특별시 강남구 논현동  225번지 6호    논현1동      다방
# ...                                    ...   ...     ...
# 13853       서울특별시 강남구 삼성동  159번지 7호  현대백화점  삼성1동     백화점
# 13854       서울특별시 강남구 삼성동  159번지 7호  현대백화점  삼성1동     백화점
# 13855            서울특별시 강남구 청담동  44번지 12호     청담동  일반조리판매
# 13856            서울특별시 강남구 청담동  44번지 12호     청담동  일반조리판매
# 13857           서울특별시 강남구 신사동  624번지 24호     신사동     커피숍
#
# [13858 rows x 6 columns]

# %%
gangseo = pd.read_csv('res_gangseo.csv', encoding = 'euc-kr')
df_gangseo =gangseo[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_gangseo[df_gangseo['폐업구분'].isnull()]
df_gangseo = df_gangseo[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_gangseo
# Out:
#         업종명               업소명  \
# 0     휴게음식점                다린
# 1     휴게음식점              코보다방
# 2     휴게음식점                 빌
# 3     휴게음식점               샘다방
# 4     휴게음식점                 수
# ...     ...               ...
# 5133  휴게음식점              멘탈플스
# 5134  휴게음식점              경성유통
# 5135  휴게음식점        마곡타로마님아카데미
# 5136  휴게음식점                준쓰
# 5137  휴게음식점  홀론카페(hoLon cafe)
#
#                                                  소재지도로명  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 5133  서울특별시 강서구 마곡중앙로 161-17 보타닉파크타워Ⅰ 지하1층 B110B111호...
# 5134         서울특별시 강서구 금낭화로 287-10 강서농협하나로마트 지하1층 (방화동)
# 5135         서울특별시 강서구 마곡중앙1로 20 마곡 M시그니처 4층 420호 (마곡동)
# 5136           서울특별시 강서구 마곡중앙4로 22 파인스퀘어 2층 비211호 (마곡동)
# 5137      서울특별시 강서구 화곡로68길 102 서울시니어스가양타워 1층 102호 (등촌동)
#
#                                             소재지지번   행정동명       업태명
# 0                       서울특별시 강서구 과해동  48번지 27호      공항동       과자점
# 1                      서울특별시 강서구 방화동  620번지 50호    방화제3동       과자점
# 2                      서울특별시 강서구 화곡동  362번지 84호    화곡제1동        다방
# 3                     서울특별시 강서구 방화동  598번지 146호    방화제2동        다방
# 4                       서울특별시 강서구 과해동  72번지 33호      공항동       과자점
# ...                                           ...    ...       ...
# 5133       서울특별시 강서구 마곡동  759번지 3호  보타닉파크타워Ⅰ-B110  가양제1동  기타 휴게음식점
# 5134      서울특별시 강서구 방화동  829번지 2호  강서농협하나로마트 지하1층  방화제3동  기타 휴게음식점
# 5135        서울특별시 강서구 마곡동  798번지 14호  (지상 4층)-420  발산제1동       커피숍
# 5136  서울특별시 강서구 마곡동  799번지 11호  파인스퀘어(지상 2층)-비211  발산제1동       커피숍
# 5137      서울특별시 강서구 등촌동  637번지  서울시니어스가양타워 1층-102  등촌제1동       커피숍
#
# [5138 rows x 6 columns]

# %%
geumcheon = pd.read_csv('res_geumcheon.csv', encoding = 'euc-kr')
df_geumcheon =geumcheon[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_geumcheon[df_geumcheon['폐업구분'].isnull()]
df_geumcheon= df_geumcheon[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_geumcheon
# Out:
#         업종명               업소명  \
# 0     휴게음식점               해다방
# 1     휴게음식점                거목
# 2     휴게음식점               다모아
# 3     휴게음식점         롯데리아구로가산점
# 4     휴게음식점               소네트
# ...     ...               ...
# 2574  휴게음식점             제이스푸드
# 2575  휴게음식점  TACO TRUCK(타코트럭)
# 2576  휴게음식점              달콤빙고
# 2577  휴게음식점          칠링독 독산역점
# 2578  휴게음식점  칠링독(chi11ingdog)
#
#                                                  소재지도로명  \
# 0               서울특별시 금천구 가산로3길 128 (가산동지하1층 (모아래길118))
# 1                서울특별시 금천구 가산로3길 78 (가산동지하1층 (모아래길 82))
# 2                     서울특별시 금천구 가산로 150 (가산동(구로동길 263))
# 3                         서울특별시 금천구 디지털로 188 지하1층 (가산동)
# 4     서울특별시 금천구 가산디지털1로 168 B동 B131호 (가산동우림라이온스밸리(가산...
# ...                                                 ...
# 2574
# 2575
# 2576
# 2577
# 2578
#
#                                                   소재지지번 행정동명    업태명
# 0              서울특별시 금천구 가산동  238번지 38호  지하1층 (모아래길118)  가산동     다방
# 1              서울특별시 금천구 가산동  235번지 49호  지하1층 (모아래길 82)  가산동     다방
# 2                   서울특별시 금천구 가산동  141번지 9호  (구로동길 263)  가산동     다방
# 3            서울특별시 금천구 가산동  60번지 27호  지하1층 (디지털단지로 285)  가산동  패스트푸드
# 4     서울특별시 금천구 가산동  371번지 28호 B 우림라이온스밸리(가산디지털 1길 7...  가산동    커피숍
# ...                                                 ...  ...    ...
# 2574                   서울특별시 금천구 가산동  707번지  안양천어린이물놀이장  가산동   푸드트럭
# 2575             서울특별시 금천구 가산동  707번지  (물놀이장~캠핑장 사이 공간)  가산동   푸드트럭
# 2576                             서울특별시 금천구 가산동  707번지    가산동   푸드트럭
# 2577              서울특별시 금천구 가산동  677번지  (독산역 2번출구 앞 광장)  가산동   푸드트럭
# 2578              서울특별시 금천구 가산동  677번지  (독산역 2번출구 앞 광장)  가산동   푸드트럭
#
# [2579 rows x 6 columns]

# %%
guro = pd.read_csv('res_guro.csv', encoding = 'euc-kr')
df_guro =guro[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_guro[df_guro['폐업구분'].isnull()]
df_guro= df_guro[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_guro
# Out:
#         업종명           업소명                                          소재지도로명  \
# 0     휴게음식점            청자
# 1     휴게음식점           은하수
# 2     휴게음식점          종점다방
# 3     휴게음식점          낙원다방
# 4     휴게음식점          은성다방
# ...     ...           ...                                             ...
# 3851  휴게음식점  맘스터치 오류동역남부점                     서울특별시 구로구 오류로8길 22 1층 (오류동)
# 3852  휴게음식점          밀크앤샵             서울특별시 구로구 경인로 662 지하2층 (신도림동 디큐브시티)
# 3853  휴게음식점       청담동꿀꽈배기      서울특별시 구로구 구로동로 148 고려대부속구로병원 지하1층 4호 (구로동)
# 3854  휴게음식점   CU 항동 10단지점  서울특별시 구로구 항동로 60 상가동 지하1층 B101호 (항동 하버라인 10단지)
# 3855  휴게음식점      우리동네 꽈배기                   서울특별시 구로구 디지털로32가길 1 1층 (구로동)
#
#                                                   소재지지번   행정동명       업태명
# 0                            서울특별시 구로구 구로동  716번지 10호    구로제2동        다방
# 1                             서울특별시 구로구 오류동  23번지 37호    오류제1동        다방
# 2                             서울특별시 구로구 가리봉동  89번지 2호     가리봉동        다방
# 3                    서울특별시 구로구 신도림동  430번지 3호  436-4226   신도림동        다방
# 4                            서울특별시 구로구 구로동  586번지 10호    구로제5동        다방
# ...                                                 ...    ...       ...
# 3851                       서울특별시 구로구 오류동  155번지 10호  1층  오류제2동     패스트푸드
# 3852                       서울특별시 구로구 신도림동  692번지  디큐브시티   신도림동       커피숍
# 3853                       서울특별시 구로구 구로동  80번지  지하1층 4호  구로제2동    일반조리판매
# 3854  서울특별시 구로구 항동  135번지 57호  하버라인 10단지  상가동 지하1층 B...     항동       편의점
# 3855                   서울특별시 구로구 구로동  1127번지 33호  1층 일부  구로제3동  기타 휴게음식점
#
# [3856 rows x 6 columns]

# %%
gwanak = pd.read_csv('res_guro.csv', encoding = 'euc-kr')
df_gwanak =gwanak[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_gwanak[df_gwanak['폐업구분'].isnull()]
df_gwanak= df_gwanak[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_gwanak
# Out:
#         업종명           업소명                                          소재지도로명  \
# 0     휴게음식점            청자
# 1     휴게음식점           은하수
# 2     휴게음식점          종점다방
# 3     휴게음식점          낙원다방
# 4     휴게음식점          은성다방
# ...     ...           ...                                             ...
# 3851  휴게음식점  맘스터치 오류동역남부점                     서울특별시 구로구 오류로8길 22 1층 (오류동)
# 3852  휴게음식점          밀크앤샵             서울특별시 구로구 경인로 662 지하2층 (신도림동 디큐브시티)
# 3853  휴게음식점       청담동꿀꽈배기      서울특별시 구로구 구로동로 148 고려대부속구로병원 지하1층 4호 (구로동)
# 3854  휴게음식점   CU 항동 10단지점  서울특별시 구로구 항동로 60 상가동 지하1층 B101호 (항동 하버라인 10단지)
# 3855  휴게음식점      우리동네 꽈배기                   서울특별시 구로구 디지털로32가길 1 1층 (구로동)
#
#                                                   소재지지번   행정동명       업태명
# 0                            서울특별시 구로구 구로동  716번지 10호    구로제2동        다방
# 1                             서울특별시 구로구 오류동  23번지 37호    오류제1동        다방
# 2                             서울특별시 구로구 가리봉동  89번지 2호     가리봉동        다방
# 3                    서울특별시 구로구 신도림동  430번지 3호  436-4226   신도림동        다방
# 4                            서울특별시 구로구 구로동  586번지 10호    구로제5동        다방
# ...                                                 ...    ...       ...
# 3851                       서울특별시 구로구 오류동  155번지 10호  1층  오류제2동     패스트푸드
# 3852                       서울특별시 구로구 신도림동  692번지  디큐브시티   신도림동       커피숍
# 3853                       서울특별시 구로구 구로동  80번지  지하1층 4호  구로제2동    일반조리판매
# 3854  서울특별시 구로구 항동  135번지 57호  하버라인 10단지  상가동 지하1층 B...     항동       편의점
# 3855                   서울특별시 구로구 구로동  1127번지 33호  1층 일부  구로제3동  기타 휴게음식점
#
# [3856 rows x 6 columns]

# %%
gwangjin = pd.read_csv('res_gwangjin.csv', encoding = 'euc-kr')
df_gwangjin =gwangjin[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_gwangjin[df_gwangjin['폐업구분'].isnull()]
df_gwangjin= df_gwangjin[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_gwangjin
# Out:
#         업종명               업소명                              소재지도로명  \
# 0     휴게음식점                인화
# 1     휴게음식점               황태자
# 2     휴게음식점                수정
# 3     휴게음식점               판도라
# 4     휴게음식점               오두막
# ...     ...               ...                                 ...
# 4037  휴게음식점             아레나피씨     서울특별시 광진구 면목로 203 대승빌딩 4층 (중곡동)
# 4038  휴게음식점              컨딩커피       서울특별시 광진구 아차산로21길 64 1층 (화양동)
# 4039  휴게음식점               샤르륵  서울특별시 광진구 아차산로40길 33 신광빌딩 1층 (자양동)
# 4040  휴게음식점           아이닉스피시방         서울특별시 광진구 자양로 46 지하1층 (자양동)
# 4041  휴게음식점  일리카페롯데백화점건대스타시티점     서울특별시 광진구 능동로 92 롯데백화점 1층 (자양동)
#
#                                  소재지지번   행정동명       업태명
# 0           서울특별시 광진구 군자동  102번지 32호      군자동        다방
# 1           서울특별시 광진구 구의동  252번지 16호    구의제1동        다방
# 2            서울특별시 광진구 자양동  36번지 30호    자양제4동        다방
# 3            서울특별시 광진구 화양동  111번지 5호      화양동        다방
# 4           서울특별시 광진구 화양동  111번지 49호      화양동        다방
# ...                                ...    ...       ...
# 4037     서울특별시 광진구 중곡동  556번지 1호  대승빌딩  중곡제3동    일반조리판매
# 4038         서울특별시 광진구 화양동  37번지 77호      화양동       커피숍
# 4039  서울특별시 광진구 자양동  229번지 45호  신광빌딩1층  자양제1동  기타 휴게음식점
# 4040      서울특별시 광진구 자양동  681번지 15호  지층  자양제2동    일반조리판매
# 4041  서울특별시 광진구 자양동  227번지 342호  롯데백화점  자양제3동       커피숍
#
# [4042 rows x 6 columns]

# %%
jongro = pd.read_csv('res_jongro.csv', encoding = 'euc-kr')
df_jongro = jongro[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_jongro[df_jongro['폐업구분'].isnull()]
df_jongro= df_jongro[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_jongro
# Out:
#         업종명                       업소명  \
# 0     휴게음식점                        청수
# 1     휴게음식점                        태을
# 2     휴게음식점                       봉다방
# 3     휴게음식점                         길
# 4     휴게음식점                        장미
# ...     ...                       ...
# 5165  휴게음식점                      숭인공간
# 5166  휴게음식점               라미스콘 앤 지민스통
# 5167  휴게음식점  베이커스 퍼센트(Bakers percent)
# 5168  휴게음식점          지에스25(GS25) 국일관점
# 5169  휴게음식점          지에스(GS)25 혜화경찰서점
#
#                                        소재지도로명  \
# 0
# 1
# 2                서울특별시 종로구 종로 313-1 (창신동지상2층)
# 3
# 4
# ...                                       ...
# 5165               서울특별시 종로구 동망산길 88 1층 (숭인동)
# 5166           서울특별시 종로구 돈화문로11나길 25 1층 (익선동)
# 5167              서울특별시 종로구 필운대로2길 3 1층 (누하동)
# 5168  서울특별시 종로구 수표로 96 국일관드림펠리스 1층 1~2호 (관수동)
# 5169      서울특별시 종로구 창경궁로 112-11 재림빌딩 1층 (인의동)
#
#                                      소재지지번         행정동명       업태명
# 0                서울특별시 종로구 장사동  147번지 2호    종로1.2.3.4가동        다방
# 1                서울특별시 종로구 공평동  119번지 0호    종로1.2.3.4가동        다방
# 2            서울특별시 종로구 창신동  154번지 1호  지상2층        창신제1동        다방
# 3                서울특별시 종로구 창신동  696번지 1호          창신제2동        다방
# 4                   서울특별시 종로구 장사동  212번지    종로1.2.3.4가동        다방
# ...                                    ...          ...       ...
# 5165         서울특별시 종로구 숭인동  24번지 8호  나무네 집        숭인제1동  기타 휴게음식점
# 5166                서울특별시 종로구 익선동  152번지    종로1.2.3.4가동       커피숍
# 5167             서울특별시 종로구 누하동  245번지 6호          청운효자동       커피숍
# 5168  서울특별시 종로구 관수동  20번지  국일관드림펠리스 1층-1~2  종로1.2.3.4가동    일반조리판매
# 5169         서울특별시 종로구 인의동  28번지 36호  재림빌딩  종로1.2.3.4가동    일반조리판매
#
# [5170 rows x 6 columns]

# %%
nowon = pd.read_csv('res_nowon.csv', encoding = 'euc-kr')
df_nowon = nowon[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_nowon[df_nowon['폐업구분'].isnull()]
df_nowon= df_nowon[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_nowon
# Out:
#         업종명           업소명                                         소재지도로명  \
# 0     휴게음식점             진
# 1     휴게음식점            황해
# 2     휴게음식점          쎌레스테
# 3     휴게음식점           길다방
# 4     휴게음식점            우성
# ...     ...           ...                                            ...
# 4048  휴게음식점  레스툴(restool)              서울특별시 노원구 동일로 1414 롯데백화점 7층 (상계동)
# 4049  휴게음식점         떡볶이정원                서울특별시 노원구 한글비석로1길 81-4 1층 (하계동)
# 4050  휴게음식점           솜타래                   서울특별시 노원구 공릉로27길 16 1층 (공릉동)
# 4051  휴게음식점         린스테이블  서울특별시 노원구 중계로 233 상가동 지하1층 109호 (중계동 청구3차아파트)
# 4052  휴게음식점       에그에그 커피              서울특별시 노원구 노원로1길 78-2 1층 좌측호 (공릉동)
#
#                                         소재지지번    행정동명     업태명
# 0                   서울특별시 노원구 상계동  101번지 9호    상계3.4동      다방
# 1                   서울특별시 노원구 공릉동  661번지 1호      공릉1동      다방
# 2                  서울특별시 노원구 공릉동  517번지 31호      공릉1동     과자점
# 3                  서울특별시 노원구 공릉동  517번지 31호      공릉1동      다방
# 4                   서울특별시 노원구 공릉동  661번지 4호      공릉1동      다방
# ...                                       ...     ...     ...
# 4048           서울특별시 노원구 상계동  713번지  롯데백화점 7층    상계2동     커피숍
# 4049              서울특별시 노원구 하계동  287번지  1층 일부    하계1동  일반조리판매
# 4050              서울특별시 노원구 공릉동  320번지 103호      공릉2동     커피숍
# 4051  서울특별시 노원구 중계동  360번지 2호 상가 청구3차아파트-B109    중계1동     커피숍
# 4052              서울특별시 노원구 공릉동  240번지 235호      공릉2동     커피숍
#
# [4053 rows x 6 columns]

# %%
seocho = pd.read_csv('res_seocho.csv', encoding = 'euc-kr')
df_seocho = seocho[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_seocho[df_seocho['폐업구분'].isnull()]
df_seocho= df_seocho[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_seocho
# Out:
#         업종명        업소명                                    소재지도로명  \
# 0     휴게음식점        피터팬
# 1     휴게음식점      훼미리마트
# 2     휴게음식점       한일다방
# 3     휴게음식점         대호
# 4     휴게음식점         동호
# ...     ...        ...                                       ...
# 7709  휴게음식점      유니언PC  서울특별시 서초구 서초대로56길 18 유니언타운 교대 지하1층 (서초동)
# 7710  휴게음식점      본 플라워        서울특별시 서초구 서초중앙로24길 5 1층 105호 (서초동)
# 7711  휴게음식점      더블딥커피   서울특별시 서초구 방배로11길 21 1층 102호 (방배동 그린빌라트)
# 7712  휴게음식점  쉬즈베이글 강남점  서울특별시 서초구 강남대로 309 코리아비지니스센타 1층 2호 (서초동)
# 7713  휴게음식점      진순자김밥      서울특별시 서초구 신반포로 176 신세계백화점 지하1층 (반포동)
#
#                                           소재지지번   행정동명     업태명
# 0                    서울특별시 서초구 방배동  777번지 20호     방배본동      다방
# 1                      서울특별시 서초구 반포동  19번지 4호    반포제4동     편의점
# 2                     서울특별시 서초구 양재동  1번지 2호  2층  양재제1동      다방
# 3                   서울특별시 서초구 서초동  1602번지 10호    서초제3동      다방
# 4               서울특별시 서초구 양재동  11번지 19  호  (지하)  양재제1동      다방
# ...                                         ...    ...     ...
# 7709   서울특별시 서초구 서초동  1670번지 15호  유니언타운 교대 지하1층  서초제1동  일반조리판매
# 7710          서울특별시 서초구 서초동  1695번지 20호  1층-105  서초제4동  일반조리판매
# 7711     서울특별시 서초구 방배동  912번지 1호  그린빌라트 1층 102호  방배제2동     커피숍
# 7712  서울특별시 서초구 서초동  1338번지 21호  코리아비지니스센타 1층-2  서초제2동  일반조리판매
# 7713              서울특별시 서초구 반포동  19번지 3호  센트럴시티  반포제4동  일반조리판매
#
# [7714 rows x 6 columns]

# %%
seodaemoon = pd.read_csv('res_seodaemoon.csv', encoding = 'euc-kr')
df_seodaemoon = seodaemoon[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_seodaemoon[df_seodaemoon['폐업구분'].isnull()]
df_seodaemoon= df_seodaemoon[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_seodaemoon
# Out:
#         업종명          업소명                                    소재지도로명  \
# 0     휴게음식점           터틀
# 1     휴게음식점          호원당
# 2     휴게음식점          노타리
# 3     휴게음식점         코드리옹
# 4     휴게음식점           역전
# ...     ...          ...                                       ...
# 4461  휴게음식점         미미에토             서울특별시 서대문구 연희로 153-4 1층 (연희동)
# 4462  휴게음식점     씨유 충정로역점  서울특별시 서대문구 서소문로 27 1층 104호 (충정로3가 충정리시온)
# 4463  휴게음식점        에이테이블            서울특별시 서대문구 북아현로24길 8 1층 (북아현동)
# 4464  휴게음식점         루루홀릭          서울특별시 서대문구 세검정로1길 120-1 1층 (홍은동)
# 4465  휴게음식점  와플대학 명지대캠퍼스              서울특별시 서대문구 거북골로 51 1층 (남가좌동)
#
#                                소재지지번    행정동명       업태명
# 0       서울특별시 서대문구 충정로3가  32번지 10호       충현동        다방
# 1         서울특별시 서대문구 대현동  54번지 24호       신촌동       과자점
# 2         서울특별시 서대문구 창천동  18번지 52호       신촌동        다방
# 3          서울특별시 서대문구 창천동  30번지 6호       신촌동        다방
# 4         서울특별시 서대문구 대현동  121번지 8호       신촌동        다방
# ...                              ...     ...       ...
# 4461      서울특별시 서대문구 연희동  81번지 19호       연희동       커피숍
# 4462  서울특별시 서대문구 충정로3가  465번지  충정리시온     충현동  기타 휴게음식점
# 4463   서울특별시 서대문구 북아현동  1번지 776호  1층     충현동       커피숍
# 4464      서울특별시 서대문구 홍은동  48번지 11호     홍은제1동       커피숍
# 4465    서울특별시 서대문구 남가좌동  343번지 50호    남가좌제2동    일반조리판매
#
# [4466 rows x 6 columns]

# %%
songpa = pd.read_csv('res_songpa.csv', encoding = 'euc-kr')
df_songpa = songpa[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_songpa[df_songpa['폐업구분'].isnull()]
df_songpa= df_songpa[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_songpa
# Out:
#         업종명               업소명  \
# 0     휴게음식점              맛탕수육
# 1     휴게음식점             코리아세븐
# 2     휴게음식점             볼라커피숍
# 3     휴게음식점              초원다방
# 4     휴게음식점              국제다방
# ...     ...               ...
# 8234  휴게음식점          딜리버리 삼전점
# 8235  휴게음식점               홍만당
# 8236  휴게음식점     커피베이 송파헬리오시티점
# 8237  휴게음식점              하늘연달
# 8238  휴게음식점  JYP-소울컵(SOULCUP)
#
#                                                  소재지도로명  \
# 0
# 1
# 2
# 3
# 4
# ...                                                 ...
# 8234                        서울특별시 송파구 삼전로2길 51 2층 (삼전동)
# 8235                서울특별시 송파구 충민로 66 가든파이브라이프 B1층 (문정동)
# 8236     서울특별시 송파구 송파대로 345 2블록 B동 지하1층 24호 (가락동 헬리오시티)
# 8237  서울특별시 송파구 위례광장로 120 상가동 1층 145호 (장지동 위례중앙푸르지오1단지)
# 8238                서울특별시 송파구 올림픽로 300 잠실롯데월드몰 2층 (신천동)
#
#                                    소재지지번  행정동명     업태명
# 0          서울특별시 송파구 삼전동  6번지 9호  (지상1층)   삼전동  일반조리판매
# 1              서울특별시 송파구 잠실동  228번지 9호    잠실본동   패스트푸드
# 2              서울특별시 송파구 풍납동  410번지 1호    풍납1동      다방
# 3             서울특별시 송파구 마천동  190번지 42호    마천1동     과자점
# 4             서울특별시 송파구 잠실동  184번지 11호    잠실본동      다방
# ...                                  ...   ...     ...
# 8234     서울특별시 송파구 삼전동  53번지 9호  일본식품아울렛   삼전동  일반조리판매
# 8235      서울특별시 송파구 문정동  634번지  가든파이브라이프  문정2동     떡카페
# 8236         서울특별시 송파구 가락동  479번지  헬리오시티  가락본동     커피숍
# 8237   서울특별시 송파구 장지동  897번지  위례중앙푸르지오1단지  문정2동     커피숍
# 8238  서울특별시 송파구 신천동  29번지  롯데월드타워앤드롯데월드몰  잠실4동     커피숍
#
# [8239 rows x 6 columns]

# %%
sungbuk = pd.read_csv('res_sungbuk.csv', encoding = 'euc-kr')
df_sungbuk = sungbuk[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_sungbuk[df_sungbuk['폐업구분'].isnull()]
df_sungbuk= df_sungbuk[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_sungbuk
# Out:
#         업종명        업소명                                          소재지도로명  \
# 0     휴게음식점  뺑뜨비성신여대분점
# 1     휴게음식점         호수
# 2     휴게음식점          영
# 3     휴게음식점     케익하우스윈
# 4     휴게음식점         연도
# ...     ...        ...                                             ...
# 4089  휴게음식점   피자센스&가든쿡   서울특별시 성북구 북악산로 913 제상가동 4층 404-2호 (돈암동 풍림아파트)
# 4090  휴게음식점      천사의미소                     서울특별시 성북구 성북로6가길 7 1층 (성북동)
# 4091  휴게음식점      알리오빠네                      서울특별시 성북구 보국문로 30 1층 (정릉동)
# 4092  휴게음식점     멜로우레시피  서울특별시 성북구 창경궁로 319-1 성북리시온오피스텔 1층 101호 (성북동1가)
# 4093  휴게음식점    블랑프리미엄펫                  서울특별시 성북구 동소문로24길 9 2층 (동선동1가)
#
#                                      소재지지번   행정동명       업태명
# 0                 서울특별시 성북구 동선동2가  165번지      동선동       과자점
# 1              서울특별시 성북구 삼선동5가  298번지 3호      삼선동        다방
# 2                 서울특별시 성북구 삼선동4가  346번지      삼선동        다방
# 3               서울특별시 성북구 삼선동2가  45번지 1호      삼선동       과자점
# 4              서울특별시 성북구 하월곡동  88번지 345호    월곡제1동        다방
# ...                                    ...    ...       ...
# 4089           서울특별시 성북구 돈암동  632번지  풍림아파트  돈암제1동     패스트푸드
# 4090          서울특별시 성북구 성북동  183번지 16호  1층    성북동  기타 휴게음식점
# 4091          서울특별시 성북구 정릉동  409번지 19호  1층  정릉제2동  기타 휴게음식점
# 4092  서울특별시 성북구 성북동1가  35번지 18호  성북리시온오피스텔    성북동  기타 휴게음식점
# 4093          서울특별시 성북구 동선동1가  121번지 20호      동선동  기타 휴게음식점
#
# [4094 rows x 6 columns]

# %%
youngsan = pd.read_csv('res_youngsan.csv', encoding = 'euc-kr')
df_youngsan = youngsan[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_youngsan[df_youngsan['폐업구분'].isnull()]
df_youngsan= df_youngsan[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_youngsan
# Out:
#         업종명             업소명                                           소재지도로명  \
# 0     휴게음식점              동심
# 1     휴게음식점              여백
# 2     휴게음식점              귀향                       서울특별시 용산구 한강대로80길 10 (남영동)
# 3     휴게음식점              해림
# 4     휴게음식점              중원
# ...     ...             ...                                              ...
# 3350  휴게음식점       파파도나스해방촌점                       서울특별시 용산구 신흥로 7 1층 (용산동2가)
# 3351  휴게음식점      GS25S서울역1호                서울특별시 용산구 청파로 378 한국철도공사 1층 (동자동)
# 3352  휴게음식점      쥬씨용산아스테리움점  서울특별시 용산구 한강대로30길 25 지1층 B116호 (한강로2가 아스테리움 용산)
# 3353  휴게음식점            스텐파크                서울특별시 용산구 녹사평대로52길 5 1층 1호 (이태원동)
# 3354  휴게음식점  GS25편의점공항철도2호점              서울특별시 용산구 청파로 378 한국철도공사 지하3층 (동자동)
#
#                                  소재지지번    행정동명     업태명
# 0           서울특별시 용산구 한강로1가  23번지 1호      한강로동      다방
# 1          서울특별시 용산구 한강로2가  351번지 0호      한강로동      다방
# 2             서울특별시 용산구 남영동  94번지 6호       남영동      다방
# 3           서울특별시 용산구 원효로2가  86번지 8호    원효로제1동      다방
# 4             서울특별시 용산구 문배동  11번지 0호    원효로제1동      다방
# ...                                ...     ...     ...
# 3350      서울특별시 용산구 용산동2가  5번지 1612호     용산2가동  일반조리판매
# 3351  서울특별시 용산구 동자동  43번지 205호  한국철도공사     남영동     편의점
# 3352  서울특별시 용산구 한강로2가  419번지  아스테리움 용산    한강로동     커피숍
# 3353           서울특별시 용산구 이태원동  635번지    이태원제2동     커피숍
# 3354  서울특별시 용산구 동자동  43번지 205호  한국철도공사     남영동     편의점
#
# [3355 rows x 6 columns]

# %%
sungdong = pd.read_csv('res_sungdong.csv', encoding = 'euc-kr')
df_sungdong = sungdong[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_sungdong[df_sungdong['폐업구분'].isnull()]
df_sungdong = df_sungdong[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_sungdong
# Out:
#         업종명       업소명                            소재지도로명  \
# 0     휴게음식점        대성
# 1     휴게음식점        성미
# 2     휴게음식점       리베로
# 3     휴게음식점    나드리커피숍
# 4     휴게음식점       학다방          서울특별시 성동구 광나루로9길 2 (송정동)
# ...     ...       ...                               ...
# 3173  휴게음식점       커어피  서울특별시 성동구 상원6길 7 1층 101호 (성수동1가)
# 3174  휴게음식점         탐  서울특별시 성동구 서울숲4길 16-30 1층 (성수동1가)
# 3175  휴게음식점  CU 마장세림점  서울특별시 성동구 마장로40길 12 1층 16호 (마장동)
# 3176  휴게음식점     송파류선생     서울특별시 성동구 서울숲4길 26 3층 (성수동1가)
# 3177  휴게음식점       백家네     서울특별시 성동구 왕십리로 108 1층 (성수동1가)
#
#                                소재지지번     행정동명       업태명
# 0          서울특별시 성동구 응봉동  200번지 1호        응봉동        다방
# 1        서울특별시 성동구 하왕십리동  395번지 0호     왕십리도선동        다방
# 2           서울특별시 성동구 금호동2가  325번지    금호2.3가동        다방
# 3        서울특별시 성동구 상왕십리동  773번지 5호     왕십리도선동        다방
# 4         서울특별시 성동구 송정동  66번지 262호        송정동        다방
# ...                              ...      ...       ...
# 3173    서울특별시 성동구 성수동1가  13번지 129호    성수1가제1동       커피숍
# 3174    서울특별시 성동구 성수동1가  668번지 98호    성수1가제1동       커피숍
# 3175       서울특별시 성동구 마장동  793번지 1호        마장동  기타 휴게음식점
# 3176    서울특별시 성동구 성수동1가  668번지 42호    성수1가제1동  기타 휴게음식점
# 3177  서울특별시 성동구 성수동1가  656번지 1069호    성수1가제1동  기타 휴게음식점
#
# [3178 rows x 6 columns]

# %%
df_dobong.to_csv("df_resdobong.csv", encoding='euc-kr')
df_dongdaemoon.to_csv("df_resdongdaemoon.csv", encoding='euc-kr')
df_dongjak.to_csv("df_resdongjak.csv", encoding='euc-kr')
df_eunpeung.to_csv("df_reseunpeung.csv", encoding='euc-kr')

df_gangbook.to_csv("df_resgangbook.csv", encoding='euc-kr')
df_gangseo.to_csv("df_resgangseo.csv", encoding='euc-kr')
df_gangnam.to_csv("df_resgangnam.csv", encoding='euc-kr')
# df_gang.to_csv("df_resgang.csv", encoding='euc-kr')

df_geumcheon.to_csv("df_resgeumcheon.csv", encoding='euc-kr')
df_guro.to_csv("df_resguro.csv", encoding='euc-kr')
df_gwanak.to_csv("df_resgwanak.csv", encoding='euc-kr')
df_gwangjin.to_csv("df_resgwangjin.csv", encoding='euc-kr')

df_jongro.to_csv("df_resjongro.csv", encoding='euc-kr')
df_nowon.to_csv("df_resnowon.csv", encoding='euc-kr')
df_seocho.to_csv("df_resseocho.csv", encoding='euc-kr')
df_seodaemoon.to_csv("df_resseodaemoon.csv", encoding='euc-kr')

df_songpa.to_csv("df_ressongpa.csv", encoding='euc-kr')
df_sungbuk.to_csv("df_ressungbuk.csv", encoding='euc-kr')
df_youngsan.to_csv("df_resyoungsan.csv", encoding='euc-kr')

# %%
df_sungdong.to_csv("df_ressungdong.csv", encoding='euc-kr')

# %%
import csv
import pandas as pd

youngdeungpo = pd.read_csv('res_youngdeungpo2.csv')


df_youngdeungpo = youngdeungpo[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_youngdeungpo[df_youngdeungpo['폐업구분'].isnull()]
df_youngdeungpo = df_youngdeungpo[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_youngdeungpo
# Out:
#         업종명             업소명                                      소재지도로명  \
# 0     휴게음식점            용궁다방
# 1     휴게음식점           린네스가든            서울특별시 영등포구 여의나루로 77-1 (여의도동102호)
# 2     휴게음식점           린네스가든            서울특별시 영등포구 여의나루로 77-1 (여의도동102호)
# 3     휴게음식점           린네스가든            서울특별시 영등포구 여의나루로 77-1 (여의도동102호)
# 4     휴게음식점            뉴욕제과
# ...     ...             ...                                         ...
# 6649  휴게음식점         종가집마님김밥         서울특별시 영등포구 신풍로 87 시장동 1층 102호 (신길동)
# 6650  휴게음식점  개런티(Guarantea)  서울특별시 영등포구 문래로 84 상가동 106호 (문래동3가 문래힐스테이트)
# 6651  휴게음식점      미니스톱여의도공원점      서울특별시 영등포구 여의공원로 68 여의도공원 3호편의점 (여의도동)
# 6652  휴게음식점             안젤로   서울특별시 영등포구 영중로 9 신세계백화점 지하1층 행사장 (영등포동4가)
# 6653  휴게음식점            달콩이？               서울특별시 영등포구 신풍로19가길 1 1층 (신길동)
#
#                                     소재지지번   행정동명       업태명
# 0            서울특별시 영등포구 문래동1가  22번지 16호      문래동        다방
# 1          서울특별시 영등포구 여의도동  24번지 2호  102호    여의동        다방
# 2          서울특별시 영등포구 여의도동  24번지 2호  102호    여의동        다방
# 3          서울특별시 영등포구 여의도동  24번지 2호  102호    여의동        다방
# 4             서울특별시 영등포구 여의도동  1번지 140호      여의동       과자점
# ...                                   ...    ...       ...
# 6649             서울특별시 영등포구 신길동  2365번지    영등포본동  기타 휴게음식점
# 6650      서울특별시 영등포구 문래동3가  94번지  문래힐스테이트    문래동       커피숍
# 6651     서울특별시 영등포구 여의도동  2번지  여의도공원관리사무소    여의동       편의점
# 6652  서울특별시 영등포구 영등포동4가  434번지 5호  신세계백화점   영등포동    일반조리판매
# 6653             서울특별시 영등포구 신길동  1547번지    신길제1동       커피숍
#
# [6654 rows x 6 columns]

# %%
df_youngdeungpo.to_csv("df_resyoungdeungpo.csv", encoding='euc-kr')

# %%
raw_data = {'col0': [1, 2, 3, 4],
            'col1': [10, 20, 30, 40],
            'col2': [100, 200, 300, 400]}

data = pd.DataFrame(raw_data)
print(data)
# Out:
#    col0  col1  col2
# 0     1    10   100
# 1     2    20   200
# 2     3    30   300
# 3     4    40   400

# %%
import csv
import pandas as pd

yangcheon = pd.read_csv('res_yangcheon.csv')


df_yangcheon = yangcheon[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명', '폐업일자', '폐업구분', '업태명']]
df_yangcheon[df_yangcheon['폐업구분'].isnull()]
df_yangcheon = df_yangcheon[['업종명', '업소명', '소재지도로명', '소재지지번', '행정동명','업태명']]
df_yangcheon
df_yangcheon.to_csv("df_resyangcheon.csv", encoding='euc-kr')
